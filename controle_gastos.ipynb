# %% [markdown]
# <a href="https://colab.research.google.com/github/tecnyca/controle-de-gastos/blob/main/controle_gastos.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
gastos = []

while True:
  print()
  print("==============================")
  print("       CONTROLE DE GASTOS")
  print("==============================")

  print()
  print("1) Adicionar gasto")
  print("2) Listar gastos")
  print("3) Ver total de gastos")
  print("4) Sair/Exit")

  opcao = input("Digite uma opção: ")
  print()

  if opcao == "1":
    descricao = input("Descrição do gasto: ")
    valor = float(input("Valor do gasto: "))

    gastos.append([descricao, valor])

    print("Gasto cadastrado!")


  elif opcao == "2":
    for gasto in gastos:
      print(f"{gasto[0]} - R${gasto[1]:.2f}")

    print(f"Gastos cadastrados: {len(gastos)}")


  elif opcao == "3":
    total = 0

    for gasto in gastos:
      total = total + gasto[1]

    print(f"Total gasto: R$ {total:.2f}")

  elif opcao == "4":
    print("Encerrando...")
    break

  else:
    print("Opção inválida!")
# Out:
# ==============================
#        CONTROLE DE GASTOS
# ==============================
#
# 1) Adicionar gasto
# 2) Listar gastos
# 3) Ver total de gastos
# 4) Sair/Exit
# Digite uma opção: 14
#
# Opção inválida!
#
# ==============================
#        CONTROLE DE GASTOS
# ==============================
#
# 1) Adicionar gasto
# 2) Listar gastos
# 3) Ver total de gastos
# 4) Sair/Exit
# Digite uma opção: 1
#
# Descrição do gasto: Cachorro
# Valor do gasto: 725.84
# Gasto cadastrado!
#
# ==============================
#        CONTROLE DE GASTOS
# ==============================
#
# 1) Adicionar gasto
# 2) Listar gastos
# 3) Ver total de gastos
# 4) Sair/Exit
# Digite uma opção: 1
#
# Descrição do gasto: Gato
# Valor do gasto: 1085.64
# Gasto cadastrado!
#
# ==============================
#        CONTROLE DE GASTOS
# ==============================
#
# 1) Adicionar gasto
# 2) Listar gastos
# 3) Ver total de gastos
# 4) Sair/Exit
# Digite uma opção: 1
#
# Descrição do gasto: Ração
# Valor do gasto: 25.40
# Gasto cadastrado!
#
# ==============================
#        CONTROLE DE GASTOS
# ==============================
#
# 1) Adicionar gasto
# 2) Listar gastos
# 3) Ver total de gastos
# 4) Sair/Exit
# Digite uma opção: 3
#
# Total gasto: R$ 1836.88
#
# ==============================
#        CONTROLE DE GASTOS
# ==============================
#
# 1) Adicionar gasto
# 2) Listar gastos
# 3) Ver total de gastos
# 4) Sair/Exit
# Digite uma opção: 4
#
# Encerrando...
